# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set visualization styles
sns.set(style='whitegrid')

# Define base directory
base_path = "/Users/sau24k/Documents/Projects/DataChain-Predict/data"

# Load datasets (fixing the path issue)
df_orders = pd.read_csv(f"{base_path}/DataCoSupplyChainDataset.csv", encoding="ISO-8859-1")
df_description = pd.read_csv(f"{base_path}/DescriptionDataCoSupplyChain.csv", encoding="ISO-8859-1")
df_logs = pd.read_csv(f"{base_path}/tokenized_access_logs.csv", encoding="ISO-8859-1")

# Display first few rows
print("\nOrders Dataset Sample:")
display(df_orders.head())

print("\nDescription Dataset Sample:")
display(df_description.head())

print("\nAccess Logs Dataset Sample:")
display(df_logs.head())
# Out:
# Orders Dataset Sample:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
# Check dataset shapes
print("\nDataset Shapes:")
print(f"Orders Dataset: {df_orders.shape}")
print(f"Description Dataset: {df_description.shape}")
print(f"Access Logs Dataset: {df_logs.shape}")

# Check for missing values
print("\nMissing Values:")
print(df_orders.isnull().sum())

# Basic statistics
print("\nBasic Statistics:")
print(df_orders.describe())
# Out:
# Dataset Shapes:
# Orders Dataset: (180519, 53)
# Description Dataset: (52, 2)
# Access Logs Dataset: (469977, 8)
#
# Missing Values:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# ...
